# %%
print ("conhcendo o comando prin")

X = 8
print (x)
# Out:
# conhcendo o comando prin
# 8

# %%
y = 10
soma = x + y
print (soma)
# Out:
# 18

# %%
nome = 'Bryan Henrique'
print (nome)
# Out:
# Bryan Henrique

# %% [markdown]
# Concatenação

# %%
x = 5
print ('O valor de x é ',x)
# Out:
# O valor de x é  5

# %%
print('o valor x é', x, 'e o dobro é', x * 2)
# Out:
# o valor x é 5 e o dobro é 10

# %%
print('Eu,', nome, 'tirei', x, 'na prova de python')
# Out:
# Eu, Bryan Henrique tirei 5 na prova de python

# %%
y = 10; z = 20 + x - y
print('declarar varias variavel na mesma linha:', y,z)
# Out:
# declarar varias variavel na mesma linha: 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print('x', type(x))

nome = 'Bryan Henrique'
print('nome', type(nome))

num = '100'
num_convert = int(num)    #coverter variavel
print('num', type(num))
print('num_conver', type(num_convert))

num_float = float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_conver <class 'int'>
# num_float 100.0

# %% [markdown]
# Input
#
# * Armazenar as informações digitadas pelo usúario em uma variavel
# * Dado armazenado sempre será um texto

# %%
Nome = input("Digite o nome do usuário ") # aguarde o usuário digitar algo
print (Nome)
# Out:
# Digite o nome do usuário Bryan
# Bryan

# %%
nome = 'Bryan Henrique'
valor = input('Digite a nota ')

print(nome, 'sua nota foi', valor)
# Out:
# Digite a nota 1
# Bryan Henrique sua nota foi 1

# %%
valor = input('Digite o valor do produto ')
print('O valor do produto é', valor)
# Out:
# Digite o valor do produto 15
# O valor do produto é 15

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2171237004.py in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
valor_convet = int(valor)
desconto = valor_convet + 5
print(desconto)
# Out:
# 20

# %%
desconto = int(valor) + 5
print(desconto)
# Out:
# 20

# %%
# if
if 5 < 10:
  print('verdade')
# Out:
# verdade

# %%
# if/else
num1 = 10
num2 = 5
if num1 > num2:
  print('O num1 é maior que o numero')
else:
  print('o num2 é o maior numero')
# Out:
# O num1 é maior que o numero

# %%
# If / Elif / Else
num1 = 10
num2 = 10
if num1 > num2:
  print('o num1 é maior que o numero')
elif num1 < num2:
  print('o num2 é o maior numero')
else:
  print('os dois são iguais')
# Out:
# os dois são iguais

# %% [markdown]
# * Condicional com operadores logicos

# %%
num1 = 1
num2 = 6
num3 = 2
if num1 > num2 and num1 > num3:
  print('o num2 é o maior numero')
else:
  print('o num1 nao é o maior numero')
# Out:
# o num1 nao é o maior numero

# %% [markdown]
# * Lista, Duplas e Dicionarios

# %%
# Lista
[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tupla
(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Dicionario
{'num1':1,'num2':2}
# Out:
# {'num1': 1, 'num2': 2}

# %% [markdown]
# * Lista

# %%
Lista = [5, 'Rodrigo', 8.9]

# %%
type (Lista)
# Out:
# list

# %%
Lista.append("Bryan") # Adicionar um elemento na lista

# %%
print (Lista)
print (Lista[1])
# Out:
# [5, 'Rodrigo', 8.9, 'Bryan', 'Bryan']
# Rodrigo

# %% [markdown]
# * Tupla

# %%
tupla = (5, 'Rodrigo', 8.9)

# %%
type(tupla)
# Out:
# tuple

# %%
tupla.append ("Augusto")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-729103322.py in <cell line: 0>()
# ----> 1 tupla.append ("Augusto")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
print(tupla)
# Out:
# (5, 'Rodrigo', 8.9)

# %% [markdown]
# * Dicionario

# %%
dicionario = {'nome':'Rodrig','cidade':'são josé dos campos'}

# %%
type(dicionario)

# %%
print(dicionario)
# Out:
# {'nome': 'Rodrig', 'cidade': 'são josé dos campos'}

# %%
print(dicionario["nome"])
# Out:
# Rodrig

# %%
dicionario ['último_nome'] = 'rebouças'

# %%
print(dicionario)
# Out:
# {'nome': 'Rodrig', 'cidade': 'são josé dos campos', 'último_nome': 'rebouças'}

# %% [markdown]
# * For
# * Estrutura de Repetição
# * Executar Comandos, enquanto percorre os itens de uma coleção

# %%
for <variável> in <coleção>:
  <<comandos>>
# Out:
#   File "/tmp/ipython-input-3474488800.py", line 1
#     for <variável> in <coleção>:
#         ^
# SyntaxError: invalid syntax

# %%
my_list = [1, 2, 3, 4, 5]
for item in my_list:
  print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Solicita o nome do usuário e o apresenta

nome_usuario = input("Por favor,insira o seu nome:")
print (f'Ola, {nome_usuario}! Bem vindo ao nosso Sistema.')


# Solicita a idade do usuário e converte para inteiro
idade_do_usuario = int(input('Por Favor,insira sua idade: '))

# Verifica se usuário é maior de idade
if idade_do_usuario >= 18:
  print('Você é maior de idade. ')

else:
  print("Você é menor de idade")
# Out:
# Por favor,insira o seu nome:bryan henrique
# Ola, bryan henrique! Bem vindo ao nosso Sistema.
# Por Favor,insira sua idade: 25
# Você é maior de idade.

# %%
if True :
  print ("Indentação incorreta")
# Out:
# Indentação incorreta

# %%
if True :
  print ("Indentação correta")
# Out:
# Indentação correta

# %%
x = 10
if x =10:
  print("Erro do Operador")
# Out:
#   File "/tmp/ipython-input-2383159490.py", line 2
#     if x =10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
x = 10
if x == 10:
  print("Operador Correto")
# Out:
# Operador Correto

# %%
idade = input("Digite sua idade:")
if idade >= 18:
  print("Maior de Idade")
# Out:
# Digite sua idade:25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2440496043.py in <cell line: 0>()
#       1 idade = input("Digite sua idade:")
# ----> 2 if idade >= 18:
#       3   print("Maior de Idade")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
  print( "Maior de Idade")
# Out:
# Digite sua idade: 25
# Maior de Idade

# %%
total  = tatol + 1
print (total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3078750746.py in <cell line: 0>()
# ----> 1 total  = tatol + 1
#       2 print (total)
#
# NameError: name 'tatol' is not defined

# %%
total = 0
t = total + 1
print(total)
# Out:
# 0

# %%
idade = 20
renda = 3000
if idade > 18 and renda > 2000 or idade <25:
  print("aprovado")
# Out:
# aprovado

# %%
idade = 20
renda = 3000
if (idade > 18 and renda > 2000) or idade < 25:
  print("Aprovado")
# Out:
# Aprovado

# %%
nome_do_usuario = input("Digite o nome do usuario ") # aguarde o usuario digitar algo
print (nome_do_usuario)
# Out:
# Digite o nome do usuario Bryan Henrique
# Bryan Henrique

# %%
# Desenvolvendo uma calculadora inteligente

Nome_usuario = input("Por Favor,insira o seu nome:")
print (f'Ólá, {Nome_usuario}! Bem Vindo a sua Calculadora Inteligente.')

# Solidaremos a sua idade, pra sua Calculadora estar Completa

Solidaremos_sua_idade = int(input('Por Favor,insira sua idade: '))

# Vamos verificar as suas cretencias se é de maior
if Solidaremos_sua_idade >=18:
  print('Você é maior de idade.')

else:
  print("Você é menor de idade")

# Calculadora em Python

while True:
  Operação  = input('Qual operação Matematica você deseja fazer? Para sair digite \'x\' e pressione ENTER: ')
  if Operação == 'x'or Operação == 'x':
    pass # Add a placeholder for now
  elif Operação == '+'or Operação == '-'or Operação == '*'or Operação == '/':
    num1 = int(input('Digite o primeiro número: '))
    num2 = int(input('Digite o segundo número: '))

  else:
    print('Informe uma opção válida!')

  if Operação =='+':
    total = num1 + num2
    print("O resultado é =", total)

  elif Operação == '-':
    total = num1 - num2
    print("O resultado é =", total)

  elif Operação == '*':
    total = num1 * num2
    print("O resultado é =", total)

  elif Operação == '/':
    total = num1 / num2
    print("O resultado é =", total)
# Out:
# Por Favor,insira o seu nome:Ana Carolina Dos Santos
# Ólá, Ana Carolina Dos Santos! Bem Vindo a sua Calculadora Inteligente.
# Por Favor,insira sua idade: 21
# Você é maior de idade.
# Qual operação Matematica você deseja fazer? Para sair digite 'x' e pressione ENTER: /
# Digite o primeiro número: 765
# Digite o segundo número: 675
# O resultado é = 1.1333333333333333
# Qual operação Matematica você deseja fazer? Para sair digite 'x' e pressione ENTER: *
# Digite o primeiro número: 987
# Digite o segundo número: 212
# O resultado é = 209244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-483075872.py in <cell line: 0>()
#      18
#      19 while True:
# ---> 20   Operação  = input('Qual operação Matematica você deseja fazer? Para sair digite \'x\' e pressione ENTER: ')
#      21   if Operação == 'x'or Operação == 'x':
# ...
